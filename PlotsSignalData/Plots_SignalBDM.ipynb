# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import exp, loadtxt, pi, sqrt
from mpl_toolkits import mplot3d

# %%
CosSunTotalMomentumReco = np.loadtxt('CosSunTotalMomentumReco.dat')
EnergyTrue = np.loadtxt('EnergyTrue.dat')
PdgReco = np.loadtxt('PdgReco.dat', dtype=str)
PrimaryVtxXTrue = np.loadtxt('PrimaryVtxXTrue.dat')
PrimaryVtxZReco = np.loadtxt('PrimaryVtxZReco.dat')
PtTotalMomentumTrue = np.loadtxt('PtTotalMomentumTrue.dat')
CosSunTotalMomentumTrue = np.loadtxt('CosSunTotalMomentumTrue.dat')
MomentumReco = np.loadtxt('MomentumReco.dat')
PdgTrue = np.loadtxt('PdgTrue.dat')
PrimaryVtxYReco = np.loadtxt('PrimaryVtxYReco.dat')
PrimaryVtxZTrue = np.loadtxt('PrimaryVtxZTrue.dat')
TotalMomentumReco = np.loadtxt('TotalMomentumReco.dat')
EnergyReco = np.loadtxt('EnergyReco.dat')
MomentumTrue = np.loadtxt('MomentumTrue.dat')
PrimaryVtxXReco = np.loadtxt('PrimaryVtxXReco.dat')
PrimaryVtxYTrue = np.loadtxt('PrimaryVtxYTrue.dat')
PtTotalMomentumReco = np.loadtxt('PtTotalMomentumReco.dat')
TotalMomentumTrue = np.loadtxt('TotalMomentumTrue.dat')

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.scatter3D(PrimaryVtxXTrue, PrimaryVtxZTrue, PrimaryVtxYTrue, c='r', marker = '.')

ax.set_xlabel('X [cm]', fontsize=20)
ax.set_ylabel('Z [cm]', fontsize=20)
ax.set_zlabel('Y[cm]', fontsize=20)
ax.set_title('True Primary Vertex Distribution')

fig, ax = plt.subplots(3, figsize=(10, 6))

ax[0].hist(PrimaryVtxXTrue, bins = 100)
ax[0].set_xlabel("Position X [cm]")
ax[0].set_ylabel("# of Vertexes")

ax[1].hist(PrimaryVtxYTrue, bins = 100)
ax[1].set_xlabel("Position Y [cm]")
ax[1].set_ylabel("# of Vertexes")

ax[2].hist(PrimaryVtxZTrue, bins = 100)
ax[2].set_xlabel("Position Z [cm]")
ax[2].set_ylabel("# of Vertexes")

fig.tight_layout()

# %%
(unique, counts) = np.unique(PdgTrue[0:196776], return_counts=True)

freq_true_b10 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_true_b10[:,0], '#Particles':freq_true_b10[:,1]}
df_true_b10 = pd.DataFrame(data=data,dtype=np.int)
df_true_b10
# Out:
#     PDG Code  #Particles
# 0        130         603
# 1        211       13236
# 2        310         604
# 3        311         430
# 4        321         855
# 5        331          36
# 6       2212      180072
# 7       3112         120
# 8       3122         651
# 9       3212          78
# 10      3222          89
# 11      3312           2

# %%
(unique, counts) = np.unique(PdgTrue[196777:229055], return_counts=True)

freq_true_b1p5 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_true_b1p5[:,0], '#Particles':freq_true_b1p5[:,1]}
df_true_b1p5 = pd.DataFrame(data=data,dtype=np.int)
df_true_b1p5
# Out:
#    PDG Code  #Particles
# 0       211        1388
# 1      2212       30890

# %%
(unique, counts) = np.unique(PdgTrue[229056:230852], return_counts=True)

freq_true_b1p1 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_true_b1p1[:,0], '#Particles':freq_true_b1p1[:,1]}
df_true_b1p1 = pd.DataFrame(data=data,dtype=np.int)
df_true_b1p1
# Out:
#    PDG Code  #Particles
# 0       211           1
# 1      2212        1795

# %%
df_true_b10.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%', title = '$\gamma = 10$' )
df_true_b1p5.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%', title = '$\gamma = 1.5$' )
df_true_b1p1.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%',  title = '$\gamma = 1.1$')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3be1efa58>],
#       dtype=object)

# %%
plt.figure(dpi=100)
plt.hist(EnergyTrue[0:196776], bins = 200,log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(EnergyTrue[196777:229055], bins = 200,log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(EnergyTrue[229056:230852], bins = 200,log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Energy Distribution, \n Visible True Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Energy [GeV]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
plt.hist(MomentumTrue[0:196776], bins = 200,log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(MomentumTrue[196777:229055], bins = 200,log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(MomentumTrue[229056:230852], bins = 200,log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Momentum Distribution \n Visible True Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Momentum [GeV/c]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
plt.hist(TotalMomentumTrue[0:8581], bins = 40, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(TotalMomentumTrue[8582:15104], bins = 40, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(TotalMomentumTrue[15105:15967], bins = 40, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Total Momentum Distribution \n Visible True Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Momentum [GeV/c/Event]') 
plt.ylabel('Number of Events')
# Out:
# Text(0, 0.5, 'Number of Events')

# %%
plt.figure(dpi=100)
plt.hist(PtTotalMomentumTrue[0:8581], bins = 40, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(PtTotalMomentumTrue[8582:15104], bins = 40, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(PtTotalMomentumTrue[15105:15967], bins = 40, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Total Momentum Distribution \n Visible True Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Transverse Momentum [GeV/c/Event]') 
plt.ylabel('Number of Events')
# Out:
# Text(0, 0.5, 'Number of Events')

# %%
plt.figure(dpi=100)
plt.hist(CosSunTotalMomentumTrue[0:8581], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(CosSunTotalMomentumTrue[8582:15104], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(CosSunTotalMomentumTrue[15105:15967], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Total Momentum Distribution \n Visible True Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper left', frameon=False)
plt.xlabel(r'$cos(\theta_{Sun})$') 
plt.ylabel('Number of Events')
# Out:
# Text(0, 0.5, 'Number of Events')

# %% [markdown]
# # Reco Information

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.scatter3D(PrimaryVtxXReco[PrimaryVtxXReco!=0], PrimaryVtxZReco[PrimaryVtxZReco!=0], PrimaryVtxYReco[PrimaryVtxYReco!=0], c='r', marker = '.')

ax.set_xlabel('X [cm]', fontsize=20)
ax.set_ylabel('Z [cm]', fontsize=20)
ax.set_zlabel('Y[cm]', fontsize=20)
ax.set_title('Reco Primary Vertex Distribution')

fig, ax = plt.subplots(3, figsize=(10, 6))

ax[0].hist(PrimaryVtxXReco[PrimaryVtxYReco!=0], bins = 100)
ax[0].set_xlabel("Position X [cm]")
ax[0].set_ylabel("# of Vertexes")

ax[1].hist(PrimaryVtxYReco[PrimaryVtxYReco!=0], bins = 100)
ax[1].set_xlabel("Position Y [cm]")
ax[1].set_ylabel("# of Vertexes")

ax[2].hist(PrimaryVtxZReco[PrimaryVtxZReco!=0], bins = 100)
ax[2].set_xlabel("Position Z [cm]")
ax[2].set_ylabel("# of Vertexes")

fig.tight_layout()

# %%
(unique, counts) = np.unique(PdgReco[0:25141], return_counts=True)

freq_reco_b10 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_reco_b10[:,0], '#Particles':freq_reco_b10[:,1]}
df_reco_b10 = pd.DataFrame(data=data,dtype=np.int)
df_reco_b10
# Out:
# /home/leoperes/.local/lib/python3.6/site-packages/numpy/core/numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
#   PDG Code  #Particles
# 0     Muon       22336
# 1   Proton        2805

# %%
(unique, counts) = np.unique(PdgReco[25142:34169], return_counts=True)

freq_reco_b1p5 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_reco_b1p5[:,0], '#Particles':freq_reco_b1p5[:,1]}
df_reco_b1p5 = pd.DataFrame(data=data,dtype=np.int)
df_reco_b1p5
# Out:
# /home/leoperes/.local/lib/python3.6/site-packages/numpy/core/numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
#   PDG Code  #Particles
# 0     Muon        7274
# 1   Proton        1753

# %%
(unique, counts) = np.unique(PdgReco[34170:35010], return_counts=True)

freq_reco_b1p1 = np.asarray((unique, counts)).T
data = {'PDG Code': freq_reco_b1p1[:,0], '#Particles':freq_reco_b1p1[:,1]}
df_reco_b1p1 = pd.DataFrame(data=data,dtype=np.int)
df_reco_b1p1
# Out:
# /home/leoperes/.local/lib/python3.6/site-packages/numpy/core/numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
#   PDG Code  #Particles
# 0     Muon         640
# 1   Proton         200

# %%
df_reco_b10.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%', title = '$\gamma = 10$')
df_reco_b1p5.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%', title = '$\gamma = 1.5$')
df_reco_b1p1.groupby(['PDG Code']).sum().plot(kind='pie', subplots=True, shadow = True,startangle=90,
figsize=(5,5), autopct='%1.1f%%', title ='$\gamma = 1.1$')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3bd931668>],
#       dtype=object)

# %%
plt.figure(dpi=100)
plt.hist(EnergyReco[0:25141], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(EnergyReco[25142:34169], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(EnergyReco[34170:35010], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Energy Distribution, \n Reco Track Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Energy [GeV]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
plt.hist(MomentumReco[0:25141], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(MomentumReco[25142:34169], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(MomentumReco[34170:35010], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Momentum Distribution \n Reco Track Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Momentum [GeV/c]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
plt.hist(TotalMomentumReco[0:8581], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(TotalMomentumReco[8582:15104], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(TotalMomentumReco[15105:15967], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Total Momentum Distribution \n Reco Track Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Momentum [GeV/c/Event]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
plt.hist(PtTotalMomentumReco[0:8581], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(PtTotalMomentumReco[8582:15104], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(PtTotalMomentumReco[15105:15967], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')
plt.title('Total Transverse Momentum Distribution \n Reco Track Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper right', frameon=False)
plt.xlabel('Transverse Momentum [GeV/c/Event]') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')

# %%
plt.figure(dpi=100)
CosSunTotalMomentumReco_b10 = CosSunTotalMomentumReco[0:8581]
CosSunTotalMomentumReco_b1p5 = CosSunTotalMomentumReco[8582:15104]
CosSunTotalMomentumReco_b1p1 = CosSunTotalMomentumReco[15105:15967]
plt.hist(CosSunTotalMomentumReco_b10[CosSunTotalMomentumReco_b10 != 0], bins = 40, log = True, color = "red", histtype='step', lw=1,label='$\gamma = 10$')
plt.hist(CosSunTotalMomentumReco_b1p5[CosSunTotalMomentumReco_b1p5 != 0], bins = 40, log = True, color = "blue", histtype='step', lw=1,label='$\gamma = 1.5$')
plt.hist(CosSunTotalMomentumReco_b1p1[CosSunTotalMomentumReco_b1p1 != 0], bins = 40, log = True, color = "green", histtype='step', lw=1,label='$\gamma =1.1$')

plt.title('Total Momentum Distribution \n Reco Track Particles, \n hA Intranuke 2018 + Bodek-Ritchie nonlocal relativistic Fermi gas')
plt.legend(loc='upper left', frameon=False)
plt.xlabel(r'$cos(\theta_{Sun})$') 
plt.ylabel('Number of particles')
# Out:
# Text(0, 0.5, 'Number of particles')
